# %%
import torch
from torch import nn
import torchvision
from PIL import Image

from gatys import Gatys
# Out:
# C:\Users\33752\anaconda3\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.1.0) or chardet (4.0.0)/charset_normalizer (2.1.1) doesn't match a supported version!
#   warnings.warn(

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
input_image = Image.open("content/Tuebingen_Neckarfront.jpg")
style_image = Image.open("style/vangogh_starry_night.jpg")

# %%
gatys_method = Gatys().to(device)

# %%
input_image.resize((200, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
style_image.resize((200, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
# random initialization
styled_input = gatys_method.transfer_style(input_image, style_image, opt_img=None)
# Out:
# Iteration: 50, loss: 1422515.500000
# Iteration: 100, loss: 33090.843750
# Iteration: 150, loss: 14287.414062
# Iteration: 200, loss: 9050.476562
# Iteration: 250, loss: 6947.489746
# Iteration: 300, loss: 5989.679688
# Iteration: 350, loss: 5437.772461
# Iteration: 400, loss: 5102.222656
# Iteration: 450, loss: 4875.008789
# Iteration: 500, loss: 4700.343750

# %%
gatys_method.display_image(styled_input)

# %%
from torch.autograd import Variable
# content initialization
opt_img = gatys_method.prep(input_image).unsqueeze(0).data.clone()
styled_input2 = gatys_method.transfer_style(input_image, style_image, opt_img=opt_img, max_iter=1000)
# Out:
# Iteration: 50, loss: 8930.613281
# Iteration: 100, loss: 5540.720703
# Iteration: 150, loss: 4736.727051
# Iteration: 200, loss: 4381.673828
# Iteration: 250, loss: 4200.240234
# Iteration: 300, loss: 4082.514648
# Iteration: 350, loss: 4003.232422
# Iteration: 400, loss: 3946.204590
# Iteration: 450, loss: 3904.408936
# Iteration: 500, loss: 3872.700195

# %%
gatys_method.display_image(styled_input2)

# %%
gatys_method.img_size = 224

styled_input_test = gatys_method.transfer_style(input_image, style_image, opt_img="content")
# Out:
# Iteration: 50, loss: 8424.613281
# Iteration: 100, loss: 5416.397461
# Iteration: 150, loss: 4689.748535
# Iteration: 200, loss: 4358.444824
# Iteration: 250, loss: 4183.662109
# Iteration: 300, loss: 4073.798828
# Iteration: 350, loss: 3994.839355
# Iteration: 400, loss: 3939.272949
# Iteration: 450, loss: 3896.216309
# Iteration: 500, loss: 3862.761230

# %%
gatys_method.display_image(styled_input_test)

# %%
# style initialization
styled_input3 = gatys_method.transfer_style(input_image, style_image, opt_img="style")
# Out:
# Iteration: 50, loss: 8576.101562
# Iteration: 100, loss: 6824.242676
# Iteration: 150, loss: 6006.346680
# Iteration: 200, loss: 5540.341309
# Iteration: 250, loss: 5225.860352
# Iteration: 300, loss: 5008.640137
# Iteration: 350, loss: 4842.000000
# Iteration: 400, loss: 4723.702148
# Iteration: 450, loss: 4629.485352
# Iteration: 500, loss: 4553.950684

# %%
gatys_method.display_image(styled_input3)
